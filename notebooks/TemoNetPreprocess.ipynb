# %%
import sys
print(sys.version)

# %%
# !wget -qnc https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# !bash Miniconda3-py37_4.12.0-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null

# %%
#!conda install -y htmd=1.22 python=3.7 -c acellera
# !conda install -c acellera -c conda-forge htmd

# %%
# !python3 --version

# %%
#@title Install dependencies (conda with python 3.9)

#install python 3.9 and dev utils
#you may not need all the dev libraries, but I haven't tested which aren't necessary.
# !sudo apt-get update -y
# !sudo apt-get install python3.9 python3.9-dev python3.9-distutils libpython3.9-dev

#change alternatives
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.7 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 2

# install pip
# !curl https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !python3 get-pip.py --force-reinstall

#install colab's dependencies
# !python3 -m pip install ipython ipython_genutils ipykernel jupyter_console prompt_toolkit httplib2 astor

# link to the old google package
# !ln -s /usr/local/lib/python3.7/dist-packages/google \
       /usr/local/lib/python3.9/dist-packages/google

# !wget -qnc https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# !bash Miniconda3-py39_4.9.2-Linux-x86_64.sh -bfp /usr/conda 2>&1 1>/dev/null
# !git clone https://github.com/gersteinlab/ThermoNet.git
# !/usr/conda/bin/conda install -y htmd -c acellera

# restart kernel

# %%
import sys
sys.path.append('/content/ThermoNet/ThermoNet/ThermoNet')
sys.path.append('/usr/conda/lib/python3.9/site-packages') # for 3.7 python version

# %%
from htmd.ui import Molecule

# %%
# Isn't working!!!!!!
import math
# math-dist() should work with Python 3.8+
print(math.dist([3,3], [6,11]))

# %%
import sys

# %%
from htmd.ui import Molecule

# %%
#@title Install dependencies
# !wget -qnc https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null
# !rm Miniconda3-latest-Linux-x86_64.sh
#!conda install -y htmd=1.22.0 python=3.7 -c acellera -c conda-forge
# !conda install -y htmd -c acellera

# %%
# !python3 --version

# %%
import sys
print(sys.version)

# %%
# !sudo update-alternatives --config python3

# %%
import sys

print(sys.version)

# %%
# !ls /usr/local/bin/python3.7

# %%
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages')

# %%
# !htmd_register

# %%
from htmd.ui import Molecule

# %%
from htmd.latest import compareVersions

compareVersions()

# %%
"{} {}\n{} {}".format('a', ",".join('a'), 'a', ",".join('aa'))

# %% [markdown]
#   Full name           : Andrey Beynarovich
#   Institutional email : peabeynarovich@gmail.com
#   Institution name    : DNU
#   City                : Dnipro
#   Country             : Ukraine

# %%
# !source activate base

import sys

print(sys.version)

# %%
# !git clone https://github.com/gersteinlab/ThermoNet.git

# %%
# !wget https://www.rosettacommons.org/download.php?token=a64t4Q78m&file=rosetta_bin_linux_3.10_bundle.tgz
